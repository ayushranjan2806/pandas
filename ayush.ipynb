# %%
import pandas as pd
import numpy as np

# %%
dict1 ={
    "Name":['ayush','piyush','priyanshu','atif'],
      "class":['cs -ds','cs-ds','cs-ds','bba'],
    "age":[19,20,21,22]
}

# %%
df= pd.DataFrame(dict1)

# %%
df
# Out:
#         Name   class  age
# 0      ayush  cs -ds   19
# 1     piyush   cs-ds   20
# 2  priyanshu   cs-ds   21
# 3       atif     bba   22

# %%
df.to_csv('ayush.csv')

# %%
df.head(2)
# Out:
#      Name   class  age
# 0   ayush  cs -ds   19
# 1  piyush   cs-ds   20

# %%
df.tail(1)
# Out:
#    Name class  age
# 3  atif   bba   22

# %%
df.to_csv('ayu.csv',index=False)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Name   class  age
# 0      ayush  cs -ds   19
# 1     piyush   cs-ds   20
# 2  priyanshu   cs-ds   21
# 3       atif     bba   22>

# %%
ayu=pd.read_csv('ranjan.csv')

# %%
ayu
# Out:
#    train no  district  speed ac\non ac
# 0      1234   danbaad    112        ac
# 1      1237  bagalpur    110       non
# 2     77887     jhasi    113        ac
# 3      7876    meerut     90       non
# 4     77667   giridih     78        ac
# 5     66557   koderma     98        ac
# 6     55477   varansi     89       non
# 7     55466      agra     89       non
# 8     55654       goa     55        ac

# %%
ayu.index=['first','second','third','fourth','sixth','seventh','eighth','ninth','tenth']

# %%
ayu
# Out:
#          train no  district  speed ac\non ac
# first        1234   danbaad    112        ac
# second       1237  bagalpur    110       non
# third       77887     jhasi    113        ac
# fourth       7876    meerut     90       non
# sixth       77667   giridih     78        ac
# seventh     66557   koderma     98        ac
# eighth      55477   varansi     89       non
# ninth       55466      agra     89       non
# tenth       55654       goa     55        ac

# %%
ser = pd.Series(np.random.rand(332))

# %%
ser

# %%
ser
# Out:
# 0      0.604519
# 1      0.791447
# 2      0.457645
# 3      0.376682
# 4      0.686104
#          ...
# 327    0.086109
# 328    0.626600
# 329    0.588116
# 330    0.594048
# 331    0.070365
# Length: 332, dtype: float64

# %%
newdf=pd.DataFrame(np.random.rand(332,6),index=np.arange(332))

# %%
newdf
# Out:
#             0         1         2         3         4         5
# 0    0.057161  0.288986  0.796123  0.787266  0.205418  0.261982
# 1    0.393719  0.779513  0.126449  0.162028  0.847094  0.793437
# 2    0.238768  0.159990  0.984938  0.918689  0.631667  0.650480
# 3    0.474346  0.712701  0.444646  0.753630  0.101230  0.075628
# 4    0.593708  0.980876  0.093474  0.546228  0.719252  0.778691
# ..        ...       ...       ...       ...       ...       ...
# 327  0.135226  0.700305  0.109222  0.803593  0.327878  0.699995
# 328  0.383095  0.941122  0.877147  0.167372  0.912926  0.589431
# 329  0.686980  0.675123  0.542352  0.902568  0.044767  0.140496
# 330  0.293575  0.185436  0.690123  0.504040  0.225170  0.044981
# 331  0.936902  0.012566  0.961279  0.067667  0.653106  0.013655
#
# [332 rows x 6 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf[1][1]="ayush"

# %%
newdf
# Out:
#             0         1         2         3         4         5
# 0    0
# %%
newdf.loc[0,0]=435

# %%
newdf
# Out:
#               0         1         2         3         4         5
# 0    435.000000  0.288986  0.796123  0.787266  0.205418  0.261982
# 1      0.393719       334  0.126449  0.162028  0.847094  0.793437
# 2      0.238768   0.15999  0.984938  0.918689  0.631667  0.650480
# 3      0.474346  0.712701  0.444646  0.753630  0.101230  0.075628
# 4      0.593708  0.980876  0.093474  0.546228  0.719252  0.778691
# ..          ...       ...       ...       ...       ...       ...
# 327    0.135226  0.700305  0.109222  0.803593  0.327878  0.699995
# 328    0.383095  0.941122  0.877147  0.167372  0.912926  0.589431
# 329    0.686980  0.675123  0.542352  0.902568  0.044767  0.140496
# 330    0.293575  0.185436  0.690123  0.504040  0.225170  0.044981
# 331    0.936902  0.012566  0.961279  0.067667  0.653106  0.013655
#
# [332 rows x 6 columns]

# %%
newdf.columns=list("ABCDEF")

# %%
newdf
# Out:
#               A         B         C         D         E         F
# 0    435.000000  0.288986  0.796123  0.787266  0.205418  0.261982
# 1      0.393719       334  0.126449  0.162028  0.847094  0.793437
# 2      0.238768   0.15999  0.984938  0.918689  0.631667  0.650480
# 3      0.474346  0.712701  0.444646  0.753630  0.101230  0.075628
# 4      0.593708  0.980876  0.093474  0.546228  0.719252  0.778691
# ..          ...       ...       ...       ...       ...       ...
# 327    0.135226  0.700305  0.109222  0.803593  0.327878  0.699995
# 328    0.383095  0.941122  0.877147  0.167372  0.912926  0.589431
# 329    0.686980  0.675123  0.542352  0.902568  0.044767  0.140496
# 330    0.293575  0.185436  0.690123  0.504040  0.225170  0.044981
# 331    0.936902  0.012566  0.961279  0.067667  0.653106  0.013655
#
# [332 rows x 6 columns]

# %%
nnewdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4480/3585803889.py in <module>
# ----> 1 nnewdf
#
# NameError: name 'nnewdf' is not defined

# %%
newdf.loc[0,0]=1123

# %%
newdf

# %%
newdf.drop(0,axis=1)

# %%
newdf.loc[[1,3],['C','E']]=11212,11232

# %%
newdf

# %%
newdf.loc[:,['C','D']]

# %%
newdf.loc[[1,4],:]

# %%
newdf=newdf.drop(0,axis=1)

# %%
newdf

# %%
newdf.loc[[1,2],['C','D']]=1121,756676

# %%
newdf

# %%
newdf.loc[(newdf['A']>.32)&(newdf['A']<.65)]

# %%
newdf.reset_index(drop=True , inplace=True)

# %%
newdf

# %%
newdf.iloc[0,4]

# %%
newdf.drop([0])

# %%
newdf.drop(['A'],axis=1)

# %%
newdf.drop(['A','B'],axis=1)

# %%
newdf.loc[:,['B']]=None

# %%
newdf.isnull()

# %%
dict1={
    "name":['ayush','ayush'],
    "age":[12,23]
}

# %%
df=pd.DataFrame(dict1)

# %%
df

# %%
df.drop_duplicates(subset=['name'],keep=False)

# %%
df.shape

# %%
df.info()

# %%
df['name'].value_counts(dropna=False)
